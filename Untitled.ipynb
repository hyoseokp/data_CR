# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
from scipy.ndimage import distance_transform_edt
from tqdm import tqdm  # notebook 환경용

# ==========================================
# 1. 설정 변수
# ==========================================
NUM_SAMPLES = 100000
INPUT_SIZE = 16
TARGET_SIZE = 128
SIGMA = 2.0
THRESHOLD = 0.45
MIN_FEATURE_SIZE = 10.0

# ==========================================
# 2. Buffer Logic (MFS)
# ==========================================
def apply_buffer_logic(binary, min_size, buffer=1.0):
    radius = min_size * 0.5
    dt = distance_transform_edt(binary)
    core = dt >= radius
    if not core.any():
        return np.zeros_like(binary, dtype=bool)
    dt_core = distance_transform_edt(~core)
    over = dt_core <= (radius + buffer)
    dt_over = distance_transform_edt(over)
    return dt_over >= buffer

def enforce_mfs_final(binary, min_size=8.0, max_iter=4):
    pad = int(min_size * 2)
    buffer_val = 1.0

    img = binary.astype(bool)
    img = np.pad(img, pad, mode="wrap")

    for _ in range(max_iter):
        prev = img
        # Solid
        img = apply_buffer_logic(img, min_size, buffer_val)
        # Void
        img = ~apply_buffer_logic(~img, min_size, buffer_val)
        # 수렴 검사
        if not np.any(img ^ prev):
            break

    # Crop 후 대각 대칭
    img = img[pad:-pad, pad:-pad]
    img = np.triu(img) | np.triu(img, 1).T
    return img

# ==========================================
# 3. 데이터 생성
# ==========================================
print(f"{TARGET_SIZE}x{TARGET_SIZE} 데이터 생성 시작")

processed_data = np.zeros((NUM_SAMPLES, 1, TARGET_SIZE, TARGET_SIZE), dtype=np.uint8)
raw_input_matrix = np.zeros((NUM_SAMPLES, 1, INPUT_SIZE, INPUT_SIZE), dtype=np.float32)

zoom_factor = TARGET_SIZE / INPUT_SIZE

# tqdm 단일 progress bar
pbar = tqdm(total=NUM_SAMPLES, unit="sample", leave=True)

for i in range(NUM_SAMPLES):
    # A. 초기 대칭 랜덤
    mat = np.random.rand(INPUT_SIZE, INPUT_SIZE)
    sym = np.triu(mat) + np.triu(mat, 1).T
    raw_input_matrix[i, 0] = sym

    # B. 업스케일 + 블러 (OpenCV)
    up = cv2.resize(sym, (TARGET_SIZE, TARGET_SIZE), interpolation=cv2.INTER_CUBIC)
    blur = cv2.GaussianBlur(up, (0, 0), SIGMA)

    binary = blur > THRESHOLD

    # C. MFS 강제
    binary = ~enforce_mfs_final(binary, MIN_FEATURE_SIZE)

    processed_data[i, 0] = binary.astype(np.uint8)

    # D. 10,000개마다 plot
    if (i) % 10000 == 0:
        plt.figure(figsize=(4, 2))
        plt.subplot(1, 2, 1)
        plt.imshow(binary, cmap="gray", origin="lower")
        plt.title(f"Sample {i+1}")
        plt.axis("off")

        plt.subplot(1, 2, 2)
        plt.imshow(np.tile(binary, (2, 2)), cmap="gray", origin="lower")
        plt.title("Tiled")
        plt.axis("off")

        plt.tight_layout()
        plt.show()

    pbar.update(1)

pbar.close()

# ==========================================
# 4. 저장
# ==========================================
np.save(r"D:\dataset\raw_input_matrix_1.npy", raw_input_matrix)
np.save(r"D:\dataset\binary_dataset_128_1.npy", processed_data)

print("데이터 생성 완료")
# Out:
# 128x128 데이터 생성 시작
#   0%|                                                                                   | 0/100000 [00:00<?, ?sample/s]
#  10%|███████                                                                | 9997/100000 [01:32<14:04, 106.62sample/s]
#  20%|█████████████▉                                                        | 19992/100000 [02:53<10:45, 124.00sample/s]
#  30%|████████████████████▉                                                 | 29989/100000 [04:14<09:30, 122.63sample/s]
#  40%|███████████████████████████▉                                          | 39999/100000 [05:35<07:57, 125.54sample/s]
#  50%|██████████████████████████████████▉                                   | 49996/100000 [06:56<06:42, 124.26sample/s]
#  60%|█████████████████████████████████████████▉                            | 59993/100000 [08:17<05:22, 124.18sample/s]
#  70%|████████████████████████████████████████████████▉                     | 69990/100000 [09:39<04:02, 123.93sample/s]
#  80%|███████████████████████████████████████████████████████▉              | 79998/100000 [11:00<02:41, 123.65sample/s]
#  90%|██████████████████████████████████████████████████████████████▉       | 89995/100000 [12:22<01:20, 124.70sample/s]
# 100%|█████████████████████████████████████████████████████████████████████| 100000/100000 [13:43<00:00, 121.48sample/s]
# 데이터 생성 완료

# %%
import os
import numpy as np
import gdstk
import cv2

# ================= 설정 =================
DATA_PATH = r"D:\dataset\binary_dataset_128_1.npy"
GDS_OUT_DIR = r"D:\dataset\gds"
os.makedirs(GDS_OUT_DIR, exist_ok=True)

# [중요] FDTD는 기본적으로 um 단위를 사용합니다.
# PIXEL 값이 0.015625라면 128픽셀일 때 2.0um가 됩니다.
PIXEL = 0.01575 

LAYER = 1
DATATYPE = 0
START_INDEX = 0
NUM_GDS = 100000

# ================= 데이터 로드 =================
if not os.path.exists(DATA_PATH):
    raise FileNotFoundError(f"❌ 데이터 파일이 없습니다: {DATA_PATH}")

data = np.load(DATA_PATH, mmap_mode="r")
print(f"🚀 GDS Generation Start...")

for i in range(NUM_GDS):
    idx = START_INDEX + i
    mask = data[idx, 0] > 0.5

    if np.sum(mask) == 0:
        continue 

    # [수정] Library 생성 시 단위를 1e-6(마이크로미터)로 명시
    lib = gdstk.Library(name=f"lib_{idx}", unit=1e-6, precision=1e-9)
    
    cell_name = f"structure_{idx}" # 05d 등 포맷 없이 심플하게
    cell = lib.new_cell(cell_name)

    # 1️⃣ Contour 추출
    img_uint8 = (mask * 255).astype(np.uint8)
    contours, hierarchy = cv2.findContours(img_uint8, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # 2️⃣ GDS 변환
    for cnt in contours:
        points = cnt.reshape(-1, 2)
        poly_points = []
        for pt in points:
            x, y = pt
            # OpenCV y축은 아래로 증가하므로, 필요 시 뒤집어야 할 수도 있지만
            # 보통 대칭 구조라면 그대로 둬도 무방합니다.
            poly_points.append((x * PIXEL, y * PIXEL))
            
        if len(poly_points) >= 3:
            polygon = gdstk.Polygon(poly_points, layer=LAYER, datatype=DATATYPE)
            cell.add(polygon)

    # 3️⃣ 저장
    # 파일명은 인덱스를 포함해 명확하게
    gds_filename = f"structure_{idx}.gds"
    gds_path = os.path.join(GDS_OUT_DIR, gds_filename)
    lib.write_gds(gds_path)

    if i % 100 == 0:
        print(f"✅ [{i}] {gds_filename} Saved.")

print("🎉 GDS 파일 생성 완료.")
# Out:
# 🚀 GDS Generation Start...
# ✅ [0] structure_0.gds Saved.
# ✅ [100] structure_100.gds Saved.
# ✅ [200] structure_200.gds Saved.
# ✅ [300] structure_300.gds Saved.
# ✅ [400] structure_400.gds Saved.
# ✅ [500] structure_500.gds Saved.
# ✅ [600] structure_600.gds Saved.
# ✅ [700] structure_700.gds Saved.
# ✅ [800] structure_800.gds Saved.
# ✅ [900] structure_900.gds Saved.
# ✅ [1000] structure_1000.gds Saved.
# ✅ [1100] structure_1100.gds Saved.
# ✅ [1200] structure_1200.gds Saved.
# ✅ [1300] structure_1300.gds Saved.
# ✅ [1400] structure_1400.gds Saved.
# ✅ [1500] structure_1500.gds Saved.
# ✅ [1600] structure_1600.gds Saved.
# ✅ [1700] structure_1700.gds Saved.
# ✅ [1800] structure_1800.gds Saved.
# ✅ [1900] structure_1900.gds Saved.
# ✅ [2000] structure_2000.gds Saved.
# ✅ [2100] structure_2100.gds Saved.
# ✅ [2200] structure_2200.gds Saved.
# ✅ [2300] structure_2300.gds Saved.
# ✅ [2400] structure_2400.gds Saved.
# ✅ [2500] structure_2500.gds Saved.
# ✅ [2600] structure_2600.gds Saved.
# ✅ [2700] structure_2700.gds Saved.
# ✅ [2800] structure_2800.gds Saved.
# ✅ [2900] structure_2900.gds Saved.
# ✅ [3000] structure_3000.gds Saved.
# ✅ [3100] structure_3100.gds Saved.
# ✅ [3200] structure_3200.gds Saved.
# ✅ [3300] structure_3300.gds Saved.
# ✅ [3400] structure_3400.gds Saved.
# ✅ [3500] structure_3500.gds Saved.
# ✅ [3600] structure_3600.gds Saved.
# ✅ [3700] structure_3700.gds Saved.
# ✅ [3800] structure_3800.gds Saved.
# ✅ [3900] structure_3900.gds Saved.
# ✅ [4000] structure_4000.gds Saved.
# ✅ [4100] structure_4100.gds Saved.
# ✅ [4200] structure_4200.gds Saved.
# ✅ [4300] structure_4300.gds Saved.
# ✅ [4400] structure_4400.gds Saved.
# ✅ [4500] structure_4500.gds Saved.
# ✅ [4600] structure_4600.gds Saved.
# ✅ [4700] structure_4700.gds Saved.
# ✅ [4800] structure_4800.gds Saved.
# ✅ [4900] structure_4900.gds Saved.
# ✅ [5000] structure_5000.gds Saved.
# ✅ [5100] structure_5100.gds Saved.
# ✅ [5200] structure_5200.gds Saved.
# ✅ [5300] structure_5300.gds Saved.
# ✅ [5400] structure_5400.gds Saved.
# ✅ [5500] structure_5500.gds Saved.
# ✅ [5600] structure_5600.gds Saved.
# ✅ [5700] structure_5700.gds Saved.
# ✅ [5800] structure_5800.gds Saved.
# ✅ [5900] structure_5900.gds Saved.
# ✅ [6000] structure_6000.gds Saved.
# ✅ [6100] structure_6100.gds Saved.
# ✅ [6200] structure_6200.gds Saved.
# ✅ [6300] structure_6300.gds Saved.
# ✅ [6400] structure_6400.gds Saved.
# ✅ [6500] structure_6500.gds Saved.
# ✅ [6600] structure_6600.gds Saved.
# ✅ [6700] structure_6700.gds Saved.
# ✅ [6800] structure_6800.gds Saved.
# ✅ [6900] structure_6900.gds Saved.
# ✅ [7000] structure_7000.gds Saved.
# ✅ [7100] structure_7100.gds Saved.
# ✅ [7200] structure_7200.gds Saved.
# ✅ [7300] structure_7300.gds Saved.
# ✅ [7400] structure_7400.gds Saved.
# ✅ [7500] structure_7500.gds Saved.
# ✅ [7600] structure_7600.gds Saved.
# ✅ [7700] structure_7700.gds Saved.
# ✅ [7800] structure_7800.gds Saved.
# ✅ [7900] structure_7900.gds Saved.
# ✅ [8000] structure_8000.gds Saved.
# ✅ [8100] structure_8100.gds Saved.
# ✅ [8200] structure_8200.gds Saved.
# ✅ [8300] structure_8300.gds Saved.
# ✅ [8400] structure_8400.gds Saved.
# ✅ [8500] structure_8500.gds Saved.
# ✅ [8600] structure_8600.gds Saved.
# ✅ [8700] structure_8700.gds Saved.
# ✅ [8800] structure_8800.gds Saved.
# ✅ [8900] structure_8900.gds Saved.
# ✅ [9000] structure_9000.gds Saved.
# ✅ [9100] structure_9100.gds Saved.
# ✅ [9200] structure_9200.gds Saved.
# ✅ [9300] structure_9300.gds Saved.
# ✅ [9400] structure_9400.gds Saved.
# ✅ [9500] structure_9500.gds Saved.
# ✅ [9600] structure_9600.gds Saved.
# ✅ [9700] structure_9700.gds Saved.
# ✅ [9800] structure_9800.gds Saved.
# ✅ [9900] structure_9900.gds Saved.
# ✅ [10000] structure_10000.gds Saved.
# ✅ [10100] structure_10100.gds Saved.
# ✅ [10200] structure_10200.gds Saved.
# ✅ [10300] structure_10300.gds Saved.
# ✅ [10400] structure_10400.gds Saved.
# ✅ [10500] structure_10500.gds Saved.
# ✅ [10600] structure_10600.gds Saved.
# ✅ [10700] structure_10700.gds Saved.
# ✅ [10800] structure_10800.gds Saved.
# ✅ [10900] structure_10900.gds Saved.
# ✅ [11000] structure_11000.gds Saved.
# ✅ [11100] structure_11100.gds Saved.
# ✅ [11200] structure_11200.gds Saved.
# ✅ [11300] structure_11300.gds Saved.
# ✅ [11400] structure_11400.gds Saved.
# ✅ [11500] structure_11500.gds Saved.
# ✅ [11600] structure_11600.gds Saved.
# ✅ [11700] structure_11700.gds Saved.
# ✅ [11800] structure_11800.gds Saved.
# ✅ [11900] structure_11900.gds Saved.
# ✅ [12000] structure_12000.gds Saved.
# ✅ [12100] structure_12100.gds Saved.
# ✅ [12200] structure_12200.gds Saved.
# ✅ [12300] structure_12300.gds Saved.
# ✅ [12400] structure_12400.gds Saved.
# ✅ [12500] structure_12500.gds Saved.
# ✅ [12600] structure_12600.gds Saved.
# ✅ [12700] structure_12700.gds Saved.
# ✅ [12800] structure_12800.gds Saved.
# ✅ [12900] structure_12900.gds Saved.
# ✅ [13000] structure_13000.gds Saved.
# ✅ [13100] structure_13100.gds Saved.
# ✅ [13200] structure_13200.gds Saved.
# ✅ [13300] structure_13300.gds Saved.
# ✅ [13400] structure_13400.gds Saved.
# ✅ [13500] structure_13500.gds Saved.
# ✅ [13600] structure_13600.gds Saved.
# ✅ [13700] structure_13700.gds Saved.
# ✅ [13800] structure_13800.gds Saved.
# ✅ [13900] structure_13900.gds Saved.
# ✅ [14000] structure_14000.gds Saved.
# ✅ [14100] structure_14100.gds Saved.
# ✅ [14200] structure_14200.gds Saved.
# ✅ [14300] structure_14300.gds Saved.
# ✅ [14400] structure_14400.gds Saved.
# ✅ [14500] structure_14500.gds Saved.
# ✅ [14600] structure_14600.gds Saved.
# ✅ [14700] structure_14700.gds Saved.
# ✅ [14800] structure_14800.gds Saved.
# ✅ [14900] structure_14900.gds Saved.
# ✅ [15000] structure_15000.gds Saved.
# ✅ [15100] structure_15100.gds Saved.
# ✅ [15200] structure_15200.gds Saved.
# ✅ [15300] structure_15300.gds Saved.
# ✅ [15400] structure_15400.gds Saved.
# ✅ [15500] structure_15500.gds Saved.
# ✅ [15600] structure_15600.gds Saved.
# ✅ [15700] structure_15700.gds Saved.
# ✅ [15800] structure_15800.gds Saved.
# ✅ [15900] structure_15900.gds Saved.
# ✅ [16000] structure_16000.gds Saved.
# ✅ [16100] structure_16100.gds Saved.
# ✅ [16200] structure_16200.gds Saved.
# ✅ [16300] structure_16300.gds Saved.
# ✅ [16400] structure_16400.gds Saved.
# ✅ [16500] structure_16500.gds Saved.
# ✅ [16600] structure_16600.gds Saved.
# ✅ [16700] structure_16700.gds Saved.
# ✅ [16800] structure_16800.gds Saved.
# ✅ [16900] structure_16900.gds Saved.
# ✅ [17000] structure_17000.gds Saved.
# ✅ [17100] structure_17100.gds Saved.
# ✅ [17200] structure_17200.gds Saved.
# ✅ [17300] structure_17300.gds Saved.
# ✅ [17400] structure_17400.gds Saved.
# ✅ [17500] structure_17500.gds Saved.
# ✅ [17600] structure_17600.gds Saved.
# ✅ [17700] structure_17700.gds Saved.
# ✅ [17800] structure_17800.gds Saved.
# ✅ [17900] structure_17900.gds Saved.
# ✅ [18000] structure_18000.gds Saved.
# ✅ [18100] structure_18100.gds Saved.
# ✅ [18200] structure_18200.gds Saved.
# ✅ [18300] structure_18300.gds Saved.
# ✅ [18400] structure_18400.gds Saved.
# ✅ [18500] structure_18500.gds Saved.
# ✅ [18600] structure_18600.gds Saved.
# ✅ [18700] structure_18700.gds Saved.
# ✅ [18800] structure_18800.gds Saved.
# ✅ [18900] structure_18900.gds Saved.
# ✅ [19000] structure_19000.gds Saved.
# ✅ [19100] structure_19100.gds Saved.
# ✅ [19200] structure_19200.gds Saved.
# ✅ [19300] structure_19300.gds Saved.
# ✅ [19400] structure_19400.gds Saved.
# ✅ [19500] structure_19500.gds Saved.
# ✅ [19600] structure_19600.gds Saved.
# ✅ [19700] structure_19700.gds Saved.
# ✅ [19800] structure_19800.gds Saved.
# ✅ [19900] structure_19900.gds Saved.
# ✅ [20000] structure_20000.gds Saved.
# ✅ [20100] structure_20100.gds Saved.
# ✅ [20200] structure_20200.gds Saved.
# ✅ [20300] structure_20300.gds Saved.
# ✅ [20400] structure_20400.gds Saved.
# ✅ [20500] structure_20500.gds Saved.
# ✅ [20600] structure_20600.gds Saved.
# ✅ [20700] structure_20700.gds Saved.
# ✅ [20800] structure_20800.gds Saved.
# ✅ [20900] structure_20900.gds Saved.
# ✅ [21000] structure_21000.gds Saved.
# ✅ [21100] structure_21100.gds Saved.
# ✅ [21200] structure_21200.gds Saved.
# ✅ [21300] structure_21300.gds Saved.
# ✅ [21400] structure_21400.gds Saved.
# ✅ [21500] structure_21500.gds Saved.
# ✅ [21600] structure_21600.gds Saved.
# ✅ [21700] structure_21700.gds Saved.
# ✅ [21800] structure_21800.gds Saved.
# ✅ [21900] structure_21900.gds Saved.
# ✅ [22000] structure_22000.gds Saved.
# ✅ [22100] structure_22100.gds Saved.
# ✅ [22200] structure_22200.gds Saved.
# ✅ [22300] structure_22300.gds Saved.
# ✅ [22400] structure_22400.gds Saved.
# ✅ [22500] structure_22500.gds Saved.
# ✅ [22600] structure_22600.gds Saved.
# ✅ [22700] structure_22700.gds Saved.
# ✅ [22800] structure_22800.gds Saved.
# ✅ [22900] structure_22900.gds Saved.
# ✅ [23000] structure_23000.gds Saved.
# ✅ [23100] structure_23100.gds Saved.
# ✅ [23200] structure_23200.gds Saved.
# ✅ [23300] structure_23300.gds Saved.
# ✅ [23400] structure_23400.gds Saved.
# ✅ [23500] structure_23500.gds Saved.
# ✅ [23600] structure_23600.gds Saved.
# ✅ [23700] structure_23700.gds Saved.
# ✅ [23800] structure_23800.gds Saved.
# ✅ [23900] structure_23900.gds Saved.
# ✅ [24000] structure_24000.gds Saved.
# ✅ [24100] structure_24100.gds Saved.
# ✅ [24200] structure_24200.gds Saved.
# ✅ [24300] structure_24300.gds Saved.
# ✅ [24400] structure_24400.gds Saved.
# ✅ [24500] structure_24500.gds Saved.
# ✅ [24600] structure_24600.gds Saved.
# ✅ [24700] structure_24700.gds Saved.
# ✅ [24800] structure_24800.gds Saved.
# ✅ [24900] structure_24900.gds Saved.
# ✅ [25000] structure_25000.gds Saved.
# ✅ [25100] structure_25100.gds Saved.
# ✅ [25200] structure_25200.gds Saved.
# ✅ [25300] structure_25300.gds Saved.
# ✅ [25400] structure_25400.gds Saved.
# ✅ [25500] structure_25500.gds Saved.
# ✅ [25600] structure_25600.gds Saved.
# ✅ [25700] structure_25700.gds Saved.
# ✅ [25800] structure_25800.gds Saved.
# ✅ [25900] structure_25900.gds Saved.
# ✅ [26000] structure_26000.gds Saved.
# ✅ [26100] structure_26100.gds Saved.
# ✅ [26200] structure_26200.gds Saved.
# ✅ [26300] structure_26300.gds Saved.
# ✅ [26400] structure_26400.gds Saved.
# ✅ [26500] structure_26500.gds Saved.
# ✅ [26600] structure_26600.gds Saved.
# ✅ [26700] structure_26700.gds Saved.
# ✅ [26800] structure_26800.gds Saved.
# ✅ [26900] structure_26900.gds Saved.
# ✅ [27000] structure_27000.gds Saved.
# ✅ [27100] structure_27100.gds Saved.
# ✅ [27200] structure_27200.gds Saved.
# ✅ [27300] structure_27300.gds Saved.
# ✅ [27400] structure_27400.gds Saved.
# ✅ [27500] structure_27500.gds Saved.
# ✅ [27600] structure_27600.gds Saved.
# ✅ [27700] structure_27700.gds Saved.
# ✅ [27800] structure_27800.gds Saved.
# ✅ [27900] structure_27900.gds Saved.
# ✅ [28000] structure_28000.gds Saved.
# ✅ [28100] structure_28100.gds Saved.
# ✅ [28200] structure_28200.gds Saved.
# ✅ [28300] structure_28300.gds Saved.
# ✅ [28400] structure_28400.gds Saved.
# ✅ [28500] structure_28500.gds Saved.
# ✅ [28600] structure_28600.gds Saved.
# ✅ [28700] structure_28700.gds Saved.
# ✅ [28800] structure_28800.gds Saved.
# ✅ [28900] structure_28900.gds Saved.
# ✅ [29000] structure_29000.gds Saved.
# ✅ [29100] structure_29100.gds Saved.
# ✅ [29200] structure_29200.gds Saved.
# ✅ [29300] structure_29300.gds Saved.
# ✅ [29400] structure_29400.gds Saved.
# ✅ [29500] structure_29500.gds Saved.
# ✅ [29600] structure_29600.gds Saved.
# ✅ [29700] structure_29700.gds Saved.
# ✅ [29800] structure_29800.gds Saved.
# ✅ [29900] structure_29900.gds Saved.
# ✅ [30000] structure_30000.gds Saved.
# ✅ [30100] structure_30100.gds Saved.
# ✅ [30200] structure_30200.gds Saved.
# ✅ [30300] structure_30300.gds Saved.
# ✅ [30400] structure_30400.gds Saved.
# ✅ [30500] structure_30500.gds Saved.
# ✅ [30600] structure_30600.gds Saved.
# ✅ [30700] structure_30700.gds Saved.
# ✅ [30800] structure_30800.gds Saved.
# ✅ [30900] structure_30900.gds Saved.
# ✅ [31000] structure_31000.gds Saved.
# ✅ [31100] structure_31100.gds Saved.
# ✅ [31200] structure_31200.gds Saved.
# ✅ [31300] structure_31300.gds Saved.
# ✅ [31400] structure_31400.gds Saved.
# ✅ [31500] structure_31500.gds Saved.
# ✅ [31600] structure_31600.gds Saved.
# ✅ [31700] structure_31700.gds Saved.
# ✅ [31800] structure_31800.gds Saved.
# ✅ [31900] structure_31900.gds Saved.
# ✅ [32000] structure_32000.gds Saved.
# ✅ [32100] structure_32100.gds Saved.
# ✅ [32200] structure_32200.gds Saved.
# ✅ [32300] structure_32300.gds Saved.
# ✅ [32400] structure_32400.gds Saved.
# ✅ [32500] structure_32500.gds Saved.
# ✅ [32600] structure_32600.gds Saved.
# ✅ [32700] structure_32700.gds Saved.
# ✅ [32800] structure_32800.gds Saved.
# ✅ [32900] structure_32900.gds Saved.
# ✅ [33000] structure_33000.gds Saved.
# ✅ [33100] structure_33100.gds Saved.
# ✅ [33200] structure_33200.gds Saved.
# ✅ [33300] structure_33300.gds Saved.
# ✅ [33400] structure_33400.gds Saved.
# ✅ [33500] structure_33500.gds Saved.
# ✅ [33600] structure_33600.gds Saved.
# ✅ [33700] structure_33700.gds Saved.
# ✅ [33800] structure_33800.gds Saved.
# ✅ [33900] structure_33900.gds Saved.
# ✅ [34000] structure_34000.gds Saved.
# ✅ [34100] structure_34100.gds Saved.
# ✅ [34200] structure_34200.gds Saved.
# ✅ [34300] structure_34300.gds Saved.
# ✅ [34400] structure_34400.gds Saved.
# ✅ [34500] structure_34500.gds Saved.
# ✅ [34600] structure_34600.gds Saved.
# ✅ [34700] structure_34700.gds Saved.
# ✅ [34800] structure_34800.gds Saved.
# ✅ [34900] structure_34900.gds Saved.
# ✅ [35000] structure_35000.gds Saved.
# ✅ [35100] structure_35100.gds Saved.
# ✅ [35200] structure_35200.gds Saved.
# ✅ [35300] structure_35300.gds Saved.
# ✅ [35400] structure_35400.gds Saved.
# ✅ [35500] structure_35500.gds Saved.
# ✅ [35600] structure_35600.gds Saved.
# ✅ [35700] structure_35700.gds Saved.
# ✅ [35800] structure_35800.gds Saved.
# ✅ [35900] structure_35900.gds Saved.
# ✅ [36000] structure_36000.gds Saved.
# ✅ [36100] structure_36100.gds Saved.
# ✅ [36200] structure_36200.gds Saved.
# ✅ [36300] structure_36300.gds Saved.
# ✅ [36400] structure_36400.gds Saved.
# ✅ [36500] structure_36500.gds Saved.
# ✅ [36600] structure_36600.gds Saved.
# ✅ [36700] structure_36700.gds Saved.
# ✅ [36800] structure_36800.gds Saved.
# ✅ [36900] structure_36900.gds Saved.
# ✅ [37000] structure_37000.gds Saved.
# ✅ [37100] structure_37100.gds Saved.
# ✅ [37200] structure_37200.gds Saved.
# ✅ [37300] structure_37300.gds Saved.
# ✅ [37400] structure_37400.gds Saved.
# ✅ [37500] structure_37500.gds Saved.
# ✅ [37600] structure_37600.gds Saved.
# ✅ [37700] structure_37700.gds Saved.
# ✅ [37800] structure_37800.gds Saved.
# ✅ [37900] structure_37900.gds Saved.
# ✅ [38000] structure_38000.gds Saved.
# ✅ [38100] structure_38100.gds Saved.
# ✅ [38200] structure_38200.gds Saved.
# ✅ [38300] structure_38300.gds Saved.
# ✅ [38400] structure_38400.gds Saved.
# ✅ [38500] structure_38500.gds Saved.
# ✅ [38600] structure_38600.gds Saved.
# ✅ [38700] structure_38700.gds Saved.
# ✅ [38800] structure_38800.gds Saved.
# ✅ [38900] structure_38900.gds Saved.
# ✅ [39000] structure_39000.gds Saved.
# ✅ [39100] structure_39100.gds Saved.
# ✅ [39200] structure_39200.gds Saved.
# ✅ [39300] structure_39300.gds Saved.
# ✅ [39400] structure_39400.gds Saved.
# ✅ [39500] structure_39500.gds Saved.
# ✅ [39600] structure_39600.gds Saved.
# ✅ [39700] structure_39700.gds Saved.
# ✅ [39800] structure_39800.gds Saved.
# ✅ [39900] structure_39900.gds Saved.
# ✅ [40000] structure_40000.gds Saved.
# ✅ [40100] structure_40100.gds Saved.
# ✅ [40200] structure_40200.gds Saved.
# ✅ [40300] structure_40300.gds Saved.
# ✅ [40400] structure_40400.gds Saved.
# ✅ [40500] structure_40500.gds Saved.
# ✅ [40600] structure_40600.gds Saved.
# ✅ [40700] structure_40700.gds Saved.
# ✅ [40800] structure_40800.gds Saved.
# ✅ [40900] structure_40900.gds Saved.
# ✅ [41000] structure_41000.gds Saved.
# ✅ [41100] structure_41100.gds Saved.
# ✅ [41200] structure_41200.gds Saved.
# ✅ [41300] structure_41300.gds Saved.
# ✅ [41400] structure_41400.gds Saved.
# ✅ [41500] structure_41500.gds Saved.
# ✅ [41600] structure_41600.gds Saved.
# ✅ [41700] structure_41700.gds Saved.
# ✅ [41800] structure_41800.gds Saved.
# ✅ [41900] structure_41900.gds Saved.
# ✅ [42000] structure_42000.gds Saved.
# ✅ [42100] structure_42100.gds Saved.
# ✅ [42200] structure_42200.gds Saved.
# ✅ [42300] structure_42300.gds Saved.
# ✅ [42400] structure_42400.gds Saved.
# ✅ [42500] structure_42500.gds Saved.
# ✅ [42600] structure_42600.gds Saved.
# ✅ [42700] structure_42700.gds Saved.
# ✅ [42800] structure_42800.gds Saved.
# ✅ [42900] structure_42900.gds Saved.
# ✅ [43000] structure_43000.gds Saved.
# ✅ [43100] structure_43100.gds Saved.
# ✅ [43200] structure_43200.gds Saved.
# ✅ [43300] structure_43300.gds Saved.
# ✅ [43400] structure_43400.gds Saved.
# ✅ [43500] structure_43500.gds Saved.
# ✅ [43600] structure_43600.gds Saved.
# ✅ [43700] structure_43700.gds Saved.
# ✅ [43800] structure_43800.gds Saved.
# ✅ [43900] structure_43900.gds Saved.
# ✅ [44000] structure_44000.gds Saved.
# ✅ [44100] structure_44100.gds Saved.
# ✅ [44200] structure_44200.gds Saved.
# ✅ [44300] structure_44300.gds Saved.
# ✅ [44400] structure_44400.gds Saved.
# ✅ [44500] structure_44500.gds Saved.
# ✅ [44600] structure_44600.gds Saved.
# ✅ [44700] structure_44700.gds Saved.
# ✅ [44800] structure_44800.gds Saved.
# ✅ [44900] structure_44900.gds Saved.
# ✅ [45000] structure_45000.gds Saved.
# ✅ [45100] structure_45100.gds Saved.
# ✅ [45200] structure_45200.gds Saved.
# ✅ [45300] structure_45300.gds Saved.
# ✅ [45400] structure_45400.gds Saved.
# ✅ [45500] structure_45500.gds Saved.
# ✅ [45600] structure_45600.gds Saved.
# ✅ [45700] structure_45700.gds Saved.
# ✅ [45800] structure_45800.gds Saved.
# ✅ [45900] structure_45900.gds Saved.
# ✅ [46000] structure_46000.gds Saved.
# ✅ [46100] structure_46100.gds Saved.
# ✅ [46200] structure_46200.gds Saved.
# ✅ [46300] structure_46300.gds Saved.
# ✅ [46400] structure_46400.gds Saved.
# ✅ [46500] structure_46500.gds Saved.
# ✅ [46600] structure_46600.gds Saved.
# ✅ [46700] structure_46700.gds Saved.
# ✅ [46800] structure_46800.gds Saved.
# ✅ [46900] structure_46900.gds Saved.
# ✅ [47000] structure_47000.gds Saved.
# ✅ [47100] structure_47100.gds Saved.
# ✅ [47200] structure_47200.gds Saved.
# ✅ [47300] structure_47300.gds Saved.
# ✅ [47400] structure_47400.gds Saved.
# ✅ [47500] structure_47500.gds Saved.
# ✅ [47600] structure_47600.gds Saved.
# ✅ [47700] structure_47700.gds Saved.
# ✅ [47800] structure_47800.gds Saved.
# ✅ [47900] structure_47900.gds Saved.
# ✅ [48000] structure_48000.gds Saved.
# ✅ [48100] structure_48100.gds Saved.
# ✅ [48200] structure_48200.gds Saved.
# ✅ [48300] structure_48300.gds Saved.
# ✅ [48400] structure_48400.gds Saved.
# ✅ [48500] structure_48500.gds Saved.
# ✅ [48600] structure_48600.gds Saved.
# ✅ [48700] structure_48700.gds Saved.
# ✅ [48800] structure_48800.gds Saved.
# ✅ [48900] structure_48900.gds Saved.
# ✅ [49000] structure_49000.gds Saved.
# ✅ [49100] structure_49100.gds Saved.
# ✅ [49200] structure_49200.gds Saved.
# ✅ [49300] structure_49300.gds Saved.
# ✅ [49400] structure_49400.gds Saved.
# ✅ [49500] structure_49500.gds Saved.
# ✅ [49600] structure_49600.gds Saved.
# ✅ [49700] structure_49700.gds Saved.
# ✅ [49800] structure_49800.gds Saved.
# ✅ [49900] structure_49900.gds Saved.
# ✅ [50000] structure_50000.gds Saved.
# ✅ [50100] structure_50100.gds Saved.
# ✅ [50200] structure_50200.gds Saved.
# ✅ [50300] structure_50300.gds Saved.
# ✅ [50400] structure_50400.gds Saved.
# ✅ [50500] structure_50500.gds Saved.
# ✅ [50600] structure_50600.gds Saved.
# ✅ [50700] structure_50700.gds Saved.
# ✅ [50800] structure_50800.gds Saved.
# ✅ [50900] structure_50900.gds Saved.
# ✅ [51000] structure_51000.gds Saved.
# ✅ [51100] structure_51100.gds Saved.
# ✅ [51200] structure_51200.gds Saved.
# ✅ [51300] structure_51300.gds Saved.
# ✅ [51400] structure_51400.gds Saved.
# ✅ [51500] structure_51500.gds Saved.
# ✅ [51600] structure_51600.gds Saved.
# ✅ [51700] structure_51700.gds Saved.
# ✅ [51800] structure_51800.gds Saved.
# ✅ [51900] structure_51900.gds Saved.
# ✅ [52000] structure_52000.gds Saved.
# ✅ [52100] structure_52100.gds Saved.
# ✅ [52200] structure_52200.gds Saved.
# ✅ [52300] structure_52300.gds Saved.
# ✅ [52400] structure_52400.gds Saved.
# ✅ [52500] structure_52500.gds Saved.
# ✅ [52600] structure_52600.gds Saved.
# ✅ [52700] structure_52700.gds Saved.
# ✅ [52800] structure_52800.gds Saved.
# ✅ [52900] structure_52900.gds Saved.
# ✅ [53000] structure_53000.gds Saved.
# ✅ [53100] structure_53100.gds Saved.
# ✅ [53200] structure_53200.gds Saved.
# ✅ [53300] structure_53300.gds Saved.
# ✅ [53400] structure_53400.gds Saved.
# ✅ [53500] structure_53500.gds Saved.
# ✅ [53600] structure_53600.gds Saved.
# ✅ [53700] structure_53700.gds Saved.
# ✅ [53800] structure_53800.gds Saved.
# ✅ [53900] structure_53900.gds Saved.
# ✅ [54000] structure_54000.gds Saved.
# ✅ [54100] structure_54100.gds Saved.
# ✅ [54200] structure_54200.gds Saved.
# ✅ [54300] structure_54300.gds Saved.
# ✅ [54400] structure_54400.gds Saved.
# ✅ [54500] structure_54500.gds Saved.
# ✅ [54600] structure_54600.gds Saved.
# ✅ [54700] structure_54700.gds Saved.
# ✅ [54800] structure_54800.gds Saved.
# ✅ [54900] structure_54900.gds Saved.
# ✅ [55000] structure_55000.gds Saved.
# ✅ [55100] structure_55100.gds Saved.
# ✅ [55200] structure_55200.gds Saved.
# ✅ [55300] structure_55300.gds Saved.
# ✅ [55400] structure_55400.gds Saved.
# ✅ [55500] structure_55500.gds Saved.
# ✅ [55600] structure_55600.gds Saved.
# ✅ [55700] structure_55700.gds Saved.
# ✅ [55800] structure_55800.gds Saved.
# ✅ [55900] structure_55900.gds Saved.
# ✅ [56000] structure_56000.gds Saved.
# ✅ [56100] structure_56100.gds Saved.
# ✅ [56200] structure_56200.gds Saved.
# ✅ [56300] structure_56300.gds Saved.
# ✅ [56400] structure_56400.gds Saved.
# ✅ [56500] structure_56500.gds Saved.
# ✅ [56600] structure_56600.gds Saved.
# ✅ [56700] structure_56700.gds Saved.
# ✅ [56800] structure_56800.gds Saved.
# ✅ [56900] structure_56900.gds Saved.
# ✅ [57000] structure_57000.gds Saved.
# ✅ [57100] structure_57100.gds Saved.
# ✅ [57200] structure_57200.gds Saved.
# ✅ [57300] structure_57300.gds Saved.
# ✅ [57400] structure_57400.gds Saved.
# ✅ [57500] structure_57500.gds Saved.
# ✅ [57600] structure_57600.gds Saved.
# ✅ [57700] structure_57700.gds Saved.
# ✅ [57800] structure_57800.gds Saved.
# ✅ [57900] structure_57900.gds Saved.
# ✅ [58000] structure_58000.gds Saved.
# ✅ [58100] structure_58100.gds Saved.
# ✅ [58200] structure_58200.gds Saved.
# ✅ [58300] structure_58300.gds Saved.
# ✅ [58400] structure_58400.gds Saved.
# ✅ [58500] structure_58500.gds Saved.
# ✅ [58600] structure_58600.gds Saved.
# ✅ [58700] structure_58700.gds Saved.
# ✅ [58800] structure_58800.gds Saved.
# ✅ [58900] structure_58900.gds Saved.
# ✅ [59000] structure_59000.gds Saved.
# ✅ [59100] structure_59100.gds Saved.
# ✅ [59200] structure_59200.gds Saved.
# ✅ [59300] structure_59300.gds Saved.
# ✅ [59400] structure_59400.gds Saved.
# ✅ [59500] structure_59500.gds Saved.
# ✅ [59600] structure_59600.gds Saved.
# ✅ [59700] structure_59700.gds Saved.
# ✅ [59800] structure_59800.gds Saved.
# ✅ [59900] structure_59900.gds Saved.
# ✅ [60000] structure_60000.gds Saved.
# ✅ [60100] structure_60100.gds Saved.
# ✅ [60200] structure_60200.gds Saved.
# ✅ [60300] structure_60300.gds Saved.
# ✅ [60400] structure_60400.gds Saved.
# ✅ [60500] structure_60500.gds Saved.
# ✅ [60600] structure_60600.gds Saved.
# ✅ [60700] structure_60700.gds Saved.
# ✅ [60800] structure_60800.gds Saved.
# ✅ [60900] structure_60900.gds Saved.
# ✅ [61000] structure_61000.gds Saved.
# ✅ [61100] structure_61100.gds Saved.
# ✅ [61200] structure_61200.gds Saved.
# ✅ [61300] structure_61300.gds Saved.
# ✅ [61400] structure_61400.gds Saved.
# ✅ [61500] structure_61500.gds Saved.
# ✅ [61600] structure_61600.gds Saved.
# ✅ [61700] structure_61700.gds Saved.
# ✅ [61800] structure_61800.gds Saved.
# ✅ [61900] structure_61900.gds Saved.
# ✅ [62000] structure_62000.gds Saved.
# ✅ [62100] structure_62100.gds Saved.
# ✅ [62200] structure_62200.gds Saved.
# ✅ [62300] structure_62300.gds Saved.
# ✅ [62400] structure_62400.gds Saved.
# ✅ [62500] structure_62500.gds Saved.
# ✅ [62600] structure_62600.gds Saved.
# ✅ [62700] structure_62700.gds Saved.
# ✅ [62800] structure_62800.gds Saved.
# ✅ [62900] structure_62900.gds Saved.
# ✅ [63000] structure_63000.gds Saved.
# ✅ [63100] structure_63100.gds Saved.
# ✅ [63200] structure_63200.gds Saved.
# ✅ [63300] structure_63300.gds Saved.
# ✅ [63400] structure_63400.gds Saved.
# ✅ [63500] structure_63500.gds Saved.
# ✅ [63600] structure_63600.gds Saved.
# ✅ [63700] structure_63700.gds Saved.
# ✅ [63800] structure_63800.gds Saved.
# ✅ [63900] structure_63900.gds Saved.
# ✅ [64000] structure_64000.gds Saved.
# ✅ [64100] structure_64100.gds Saved.
# ✅ [64200] structure_64200.gds Saved.
# ✅ [64300] structure_64300.gds Saved.
# ✅ [64400] structure_64400.gds Saved.
# ✅ [64500] structure_64500.gds Saved.
# ✅ [64600] structure_64600.gds Saved.
# ✅ [64700] structure_64700.gds Saved.
# ✅ [64800] structure_64800.gds Saved.
# ✅ [64900] structure_64900.gds Saved.
# ✅ [65000] structure_65000.gds Saved.
# ✅ [65100] structure_65100.gds Saved.
# ✅ [65200] structure_65200.gds Saved.
# ✅ [65300] structure_65300.gds Saved.
# ✅ [65400] structure_65400.gds Saved.
# ✅ [65500] structure_65500.gds Saved.
# ✅ [65600] structure_65600.gds Saved.
# ✅ [65700] structure_65700.gds Saved.
# ✅ [65800] structure_65800.gds Saved.
# ✅ [65900] structure_65900.gds Saved.
# ✅ [66000] structure_66000.gds Saved.
# ✅ [66100] structure_66100.gds Saved.
# ✅ [66200] structure_66200.gds Saved.
# ✅ [66300] structure_66300.gds Saved.
# ✅ [66400] structure_66400.gds Saved.
# ✅ [66500] structure_66500.gds Saved.
# ✅ [66600] structure_66600.gds Saved.
# ✅ [66700] structure_66700.gds Saved.
# ✅ [66800] structure_66800.gds Saved.
# ✅ [66900] structure_66900.gds Saved.
# ✅ [67000] structure_67000.gds Saved.
# ✅ [67100] structure_67100.gds Saved.
# ✅ [67200] structure_67200.gds Saved.
# ✅ [67300] structure_67300.gds Saved.
# ✅ [67400] structure_67400.gds Saved.
# ✅ [67500] structure_67500.gds Saved.
# ✅ [67600] structure_67600.gds Saved.
# ✅ [67700] structure_67700.gds Saved.
# ✅ [67800] structure_67800.gds Saved.
# ✅ [67900] structure_67900.gds Saved.
# ✅ [68000] structure_68000.gds Saved.
# ✅ [68100] structure_68100.gds Saved.
# ✅ [68200] structure_68200.gds Saved.
# ✅ [68300] structure_68300.gds Saved.
# ✅ [68400] structure_68400.gds Saved.
# ✅ [68500] structure_68500.gds Saved.
# ✅ [68600] structure_68600.gds Saved.
# ✅ [68700] structure_68700.gds Saved.
# ✅ [68800] structure_68800.gds Saved.
# ✅ [68900] structure_68900.gds Saved.
# ✅ [69000] structure_69000.gds Saved.
# ✅ [69100] structure_69100.gds Saved.
# ✅ [69200] structure_69200.gds Saved.
# ✅ [69300] structure_69300.gds Saved.
# ✅ [69400] structure_69400.gds Saved.
# ✅ [69500] structure_69500.gds Saved.
# ✅ [69600] structure_69600.gds Saved.
# ✅ [69700] structure_69700.gds Saved.
# ✅ [69800] structure_69800.gds Saved.
# ✅ [69900] structure_69900.gds Saved.
# ✅ [70000] structure_70000.gds Saved.
# ✅ [70100] structure_70100.gds Saved.
# ✅ [70200] structure_70200.gds Saved.
# ✅ [70300] structure_70300.gds Saved.
# ✅ [70400] structure_70400.gds Saved.
# ✅ [70500] structure_70500.gds Saved.
# ✅ [70600] structure_70600.gds Saved.
# ✅ [70700] structure_70700.gds Saved.
# ✅ [70800] structure_70800.gds Saved.
# ✅ [70900] structure_70900.gds Saved.
# ✅ [71000] structure_71000.gds Saved.
# ✅ [71100] structure_71100.gds Saved.
# ✅ [71200] structure_71200.gds Saved.
# ✅ [71300] structure_71300.gds Saved.
# ✅ [71400] structure_71400.gds Saved.
# ✅ [71500] structure_71500.gds Saved.
# ✅ [71600] structure_71600.gds Saved.
# ✅ [71700] structure_71700.gds Saved.
# ✅ [71800] structure_71800.gds Saved.
# ✅ [71900] structure_71900.gds Saved.
# ✅ [72000] structure_72000.gds Saved.
# ✅ [72100] structure_72100.gds Saved.
# ✅ [72200] structure_72200.gds Saved.
# ✅ [72300] structure_72300.gds Saved.
# ✅ [72400] structure_72400.gds Saved.
# ✅ [72500] structure_72500.gds Saved.
# ✅ [72600] structure_72600.gds Saved.
# ✅ [72700] structure_72700.gds Saved.
# ✅ [72800] structure_72800.gds Saved.
# ✅ [72900] structure_72900.gds Saved.
# ✅ [73000] structure_73000.gds Saved.
# ✅ [73100] structure_73100.gds Saved.
# ✅ [73200] structure_73200.gds Saved.
# ✅ [73300] structure_73300.gds Saved.
# ✅ [73400] structure_73400.gds Saved.
# ✅ [73500] structure_73500.gds Saved.
# ✅ [73600] structure_73600.gds Saved.
# ✅ [73700] structure_73700.gds Saved.
# ✅ [73800] structure_73800.gds Saved.
# ✅ [73900] structure_73900.gds Saved.
# ✅ [74000] structure_74000.gds Saved.
# ✅ [74100] structure_74100.gds Saved.
# ✅ [74200] structure_74200.gds Saved.
# ✅ [74300] structure_74300.gds Saved.
# ✅ [74400] structure_74400.gds Saved.
# ✅ [74500] structure_74500.gds Saved.
# ✅ [74600] structure_74600.gds Saved.
# ✅ [74700] structure_74700.gds Saved.
# ✅ [74800] structure_74800.gds Saved.
# ✅ [74900] structure_74900.gds Saved.
# ✅ [75000] structure_75000.gds Saved.
# ✅ [75100] structure_75100.gds Saved.
# ✅ [75200] structure_75200.gds Saved.
# ✅ [75300] structure_75300.gds Saved.
# ✅ [75400] structure_75400.gds Saved.
# ✅ [75500] structure_75500.gds Saved.
# ✅ [75600] structure_75600.gds Saved.
# ✅ [75700] structure_75700.gds Saved.
# ✅ [75800] structure_75800.gds Saved.
# ✅ [75900] structure_75900.gds Saved.
# ✅ [76000] structure_76000.gds Saved.
# ✅ [76100] structure_76100.gds Saved.
# ✅ [76200] structure_76200.gds Saved.
# ✅ [76300] structure_76300.gds Saved.
# ✅ [76400] structure_76400.gds Saved.
# ✅ [76500] structure_76500.gds Saved.
# ✅ [76600] structure_76600.gds Saved.
# ✅ [76700] structure_76700.gds Saved.
# ✅ [76800] structure_76800.gds Saved.
# ✅ [76900] structure_76900.gds Saved.
# ✅ [77000] structure_77000.gds Saved.
# ✅ [77100] structure_77100.gds Saved.
# ✅ [77200] structure_77200.gds Saved.
# ✅ [77300] structure_77300.gds Saved.
# ✅ [77400] structure_77400.gds Saved.
# ✅ [77500] structure_77500.gds Saved.
# ✅ [77600] structure_77600.gds Saved.
# ✅ [77700] structure_77700.gds Saved.
# ✅ [77800] structure_77800.gds Saved.
# ✅ [77900] structure_77900.gds Saved.
# ✅ [78000] structure_78000.gds Saved.
# ✅ [78100] structure_78100.gds Saved.
# ✅ [78200] structure_78200.gds Saved.
# ✅ [78300] structure_78300.gds Saved.
# ✅ [78400] structure_78400.gds Saved.
# ✅ [78500] structure_78500.gds Saved.
# ✅ [78600] structure_78600.gds Saved.
# ✅ [78700] structure_78700.gds Saved.
# ✅ [78800] structure_78800.gds Saved.
# ✅ [78900] structure_78900.gds Saved.
# ✅ [79000] structure_79000.gds Saved.
# ✅ [79100] structure_79100.gds Saved.
# ✅ [79200] structure_79200.gds Saved.
# ✅ [79300] structure_79300.gds Saved.
# ✅ [79400] structure_79400.gds Saved.
# ✅ [79500] structure_79500.gds Saved.
# ✅ [79600] structure_79600.gds Saved.
# ✅ [79700] structure_79700.gds Saved.
# ✅ [79800] structure_79800.gds Saved.
# ✅ [79900] structure_79900.gds Saved.
# ✅ [80000] structure_80000.gds Saved.
# ✅ [80100] structure_80100.gds Saved.
# ✅ [80200] structure_80200.gds Saved.
# ✅ [80300] structure_80300.gds Saved.
# ✅ [80400] structure_80400.gds Saved.
# ✅ [80500] structure_80500.gds Saved.
# ✅ [80600] structure_80600.gds Saved.
# ✅ [80700] structure_80700.gds Saved.
# ✅ [80800] structure_80800.gds Saved.
# ✅ [80900] structure_80900.gds Saved.
# ✅ [81000] structure_81000.gds Saved.
# ✅ [81100] structure_81100.gds Saved.
# ✅ [81200] structure_81200.gds Saved.
# ✅ [81300] structure_81300.gds Saved.
# ✅ [81400] structure_81400.gds Saved.
# ✅ [81500] structure_81500.gds Saved.
# ✅ [81600] structure_81600.gds Saved.
# ✅ [81700] structure_81700.gds Saved.
# ✅ [81800] structure_81800.gds Saved.
# ✅ [81900] structure_81900.gds Saved.
# ✅ [82000] structure_82000.gds Saved.
# ✅ [82100] structure_82100.gds Saved.
# ✅ [82200] structure_82200.gds Saved.
# ✅ [82300] structure_82300.gds Saved.
# ✅ [82400] structure_82400.gds Saved.
# ✅ [82500] structure_82500.gds Saved.
# ✅ [82600] structure_82600.gds Saved.
# ✅ [82700] structure_82700.gds Saved.
# ✅ [82800] structure_82800.gds Saved.
# ✅ [82900] structure_82900.gds Saved.
# ✅ [83000] structure_83000.gds Saved.
# ✅ [83100] structure_83100.gds Saved.
# ✅ [83200] structure_83200.gds Saved.
# ✅ [83300] structure_83300.gds Saved.
# ✅ [83400] structure_83400.gds Saved.
# ✅ [83500] structure_83500.gds Saved.
# ✅ [83600] structure_83600.gds Saved.
# ✅ [83700] structure_83700.gds Saved.
# ✅ [83800] structure_83800.gds Saved.
# ✅ [83900] structure_83900.gds Saved.
# ✅ [84000] structure_84000.gds Saved.
# ✅ [84100] structure_84100.gds Saved.
# ✅ [84200] structure_84200.gds Saved.
# ✅ [84300] structure_84300.gds Saved.
# ✅ [84400] structure_84400.gds Saved.
# ✅ [84500] structure_84500.gds Saved.
# ✅ [84600] structure_84600.gds Saved.
# ✅ [84700] structure_84700.gds Saved.
# ✅ [84800] structure_84800.gds Saved.
# ✅ [84900] structure_84900.gds Saved.
# ✅ [85000] structure_85000.gds Saved.
# ✅ [85100] structure_85100.gds Saved.
# ✅ [85200] structure_85200.gds Saved.
# ✅ [85300] structure_85300.gds Saved.
# ✅ [85400] structure_85400.gds Saved.
# ✅ [85500] structure_85500.gds Saved.
# ✅ [85600] structure_85600.gds Saved.
# ✅ [85700] structure_85700.gds Saved.
# ✅ [85800] structure_85800.gds Saved.
# ✅ [85900] structure_85900.gds Saved.
# ✅ [86000] structure_86000.gds Saved.
# ✅ [86100] structure_86100.gds Saved.
# ✅ [86200] structure_86200.gds Saved.
# ✅ [86300] structure_86300.gds Saved.
# ✅ [86400] structure_86400.gds Saved.
# ✅ [86500] structure_86500.gds Saved.
# ✅ [86600] structure_86600.gds Saved.
# ✅ [86700] structure_86700.gds Saved.
# ✅ [86800] structure_86800.gds Saved.
# ✅ [86900] structure_86900.gds Saved.
# ✅ [87000] structure_87000.gds Saved.
# ✅ [87100] structure_87100.gds Saved.
# ✅ [87200] structure_87200.gds Saved.
# ✅ [87300] structure_87300.gds Saved.
# ✅ [87400] structure_87400.gds Saved.
# ✅ [87500] structure_87500.gds Saved.
# ✅ [87600] structure_87600.gds Saved.
# ✅ [87700] structure_87700.gds Saved.
# ✅ [87800] structure_87800.gds Saved.
# ✅ [87900] structure_87900.gds Saved.
# ✅ [88000] structure_88000.gds Saved.
# ✅ [88100] structure_88100.gds Saved.
# ✅ [88200] structure_88200.gds Saved.
# ✅ [88300] structure_88300.gds Saved.
# ✅ [88400] structure_88400.gds Saved.
# ✅ [88500] structure_88500.gds Saved.
# ✅ [88600] structure_88600.gds Saved.
# ✅ [88700] structure_88700.gds Saved.
# ✅ [88800] structure_88800.gds Saved.
# ✅ [88900] structure_88900.gds Saved.
# ✅ [89000] structure_89000.gds Saved.
# ✅ [89100] structure_89100.gds Saved.
# ✅ [89200] structure_89200.gds Saved.
# ✅ [89300] structure_89300.gds Saved.
# ✅ [89400] structure_89400.gds Saved.
# ✅ [89500] structure_89500.gds Saved.
# ✅ [89600] structure_89600.gds Saved.
# ✅ [89700] structure_89700.gds Saved.
# ✅ [89800] structure_89800.gds Saved.
# ✅ [89900] structure_89900.gds Saved.
# ✅ [90000] structure_90000.gds Saved.
# ✅ [90100] structure_90100.gds Saved.
# ✅ [90200] structure_90200.gds Saved.
# ✅ [90300] structure_90300.gds Saved.
# ✅ [90400] structure_90400.gds Saved.
# ✅ [90500] structure_90500.gds Saved.
# ✅ [90600] structure_90600.gds Saved.
# ✅ [90700] structure_90700.gds Saved.
# ✅ [90800] structure_90800.gds Saved.
# ✅ [90900] structure_90900.gds Saved.
# ✅ [91000] structure_91000.gds Saved.
# ✅ [91100] structure_91100.gds Saved.
# ✅ [91200] structure_91200.gds Saved.
# ✅ [91300] structure_91300.gds Saved.
# ✅ [91400] structure_91400.gds Saved.
# ✅ [91500] structure_91500.gds Saved.
# ✅ [91600] structure_91600.gds Saved.
# ✅ [91700] structure_91700.gds Saved.
# ✅ [91800] structure_91800.gds Saved.
# ✅ [91900] structure_91900.gds Saved.
# ✅ [92000] structure_92000.gds Saved.
# ✅ [92100] structure_92100.gds Saved.
# ✅ [92200] structure_92200.gds Saved.
# ✅ [92300] structure_92300.gds Saved.
# ✅ [92400] structure_92400.gds Saved.
# ✅ [92500] structure_92500.gds Saved.
# ✅ [92600] structure_92600.gds Saved.
# ✅ [92700] structure_92700.gds Saved.
# ✅ [92800] structure_92800.gds Saved.
# ✅ [92900] structure_92900.gds Saved.
# ✅ [93000] structure_93000.gds Saved.
# ✅ [93100] structure_93100.gds Saved.
# ✅ [93200] structure_93200.gds Saved.
# ✅ [93300] structure_93300.gds Saved.
# ✅ [93400] structure_93400.gds Saved.
# ✅ [93500] structure_93500.gds Saved.
# ✅ [93600] structure_93600.gds Saved.
# ✅ [93700] structure_93700.gds Saved.
# ✅ [93800] structure_93800.gds Saved.
# ✅ [93900] structure_93900.gds Saved.
# ✅ [94000] structure_94000.gds Saved.
# ✅ [94100] structure_94100.gds Saved.
# ✅ [94200] structure_94200.gds Saved.
# ✅ [94300] structure_94300.gds Saved.
# ✅ [94400] structure_94400.gds Saved.
# ✅ [94500] structure_94500.gds Saved.
# ✅ [94600] structure_94600.gds Saved.
# ✅ [94700] structure_94700.gds Saved.
# ✅ [94800] structure_94800.gds Saved.
# ✅ [94900] structure_94900.gds Saved.
# ✅ [95000] structure_95000.gds Saved.
# ✅ [95100] structure_95100.gds Saved.
# ✅ [95200] structure_95200.gds Saved.
# ✅ [95300] structure_95300.gds Saved.
# ✅ [95400] structure_95400.gds Saved.
# ✅ [95500] structure_95500.gds Saved.
# ✅ [95600] structure_95600.gds Saved.
# ✅ [95700] structure_95700.gds Saved.
# ✅ [95800] structure_95800.gds Saved.
# ✅ [95900] structure_95900.gds Saved.
# ✅ [96000] structure_96000.gds Saved.
# ✅ [96100] structure_96100.gds Saved.
# ✅ [96200] structure_96200.gds Saved.
# ✅ [96300] structure_96300.gds Saved.
# ✅ [96400] structure_96400.gds Saved.
# ✅ [96500] structure_96500.gds Saved.
# ✅ [96600] structure_96600.gds Saved.
# ✅ [96700] structure_96700.gds Saved.
# ✅ [96800] structure_96800.gds Saved.
# ✅ [96900] structure_96900.gds Saved.
# ✅ [97000] structure_97000.gds Saved.
# ✅ [97100] structure_97100.gds Saved.
# ✅ [97200] structure_97200.gds Saved.
# ✅ [97300] structure_97300.gds Saved.
# ✅ [97400] structure_97400.gds Saved.
# ✅ [97500] structure_97500.gds Saved.
# ✅ [97600] structure_97600.gds Saved.
# ✅ [97700] structure_97700.gds Saved.
# ✅ [97800] structure_97800.gds Saved.
# ✅ [97900] structure_97900.gds Saved.
# ✅ [98000] structure_98000.gds Saved.
# ✅ [98100] structure_98100.gds Saved.
# ✅ [98200] structure_98200.gds Saved.
# ✅ [98300] structure_98300.gds Saved.
# ✅ [98400] structure_98400.gds Saved.
# ✅ [98500] structure_98500.gds Saved.
# ✅ [98600] structure_98600.gds Saved.
# ✅ [98700] structure_98700.gds Saved.
# ✅ [98800] structure_98800.gds Saved.
# ✅ [98900] structure_98900.gds Saved.
# ✅ [99000] structure_99000.gds Saved.
# ✅ [99100] structure_99100.gds Saved.
# ✅ [99200] structure_99200.gds Saved.
# ✅ [99300] structure_99300.gds Saved.
# ✅ [99400] structure_99400.gds Saved.
# ✅ [99500] structure_99500.gds Saved.
# ✅ [99600] structure_99600.gds Saved.
# ✅ [99700] structure_99700.gds Saved.
# ✅ [99800] structure_99800.gds Saved.
# ✅ [99900] structure_99900.gds Saved.
# 🎉 GDS 파일 생성 완료.

# %%
import sys
import os
import time
import traceback
import gc
import subprocess
import csv
from io import StringIO
import threading

import numpy as np
import matplotlib.pyplot as plt

from tqdm import tqdm  # 텍스트 tqdm 강제(위젯 로딩/중복 출력 이슈 회피)
from IPython.display import display
# %matplotlib inline

# ==========================================
# Warning 무시 (lumapi import 전에)
# ==========================================
import warnings
warnings.filterwarnings("ignore", category=SyntaxWarning)

# ==========================================
# [중요] Jupyter Notebook 환경 변수 설정
# ==========================================
LUMERICAL_BASE = r"C:\Program Files\Lumerical\v241"
API_PATH = os.path.join(LUMERICAL_BASE, "api", "python")
BIN_PATH = os.path.join(LUMERICAL_BASE, "bin")

if API_PATH not in sys.path:
    sys.path.append(API_PATH)
if BIN_PATH not in os.environ.get("PATH", ""):
    os.environ["PATH"] = os.environ.get("PATH", "") + ";" + BIN_PATH

import lumapi

# ==========================
# 1. 설정 및 경로
# ==========================
GDS_DIR          = r"D:\dataset\gds"
FDTD_FILE        = r"D:\dataset\air_SiN_2um_NA.fsp"
RESULT_FILE      = r"D:\dataset\spectra_result\spectra_latest_1.npy"
VALID_FILE       = r"D:\dataset\spectra_result\spectra_latest_valid_1.npy"
STRUCT_DATA_PATH = r"D:\dataset\binary_dataset_128_1.npy"
LOG_FILE         = r"D:\dataset\spectra_result\run_failures.log"
PROGRESS_FILE    = r"D:\dataset\spectra_result\progress_checkpoint_1.txt"

def norm_path(p: str) -> str:
    return os.path.abspath(p).replace("\\", "/")

GDS_DIR          = norm_path(GDS_DIR)
FDTD_FILE        = norm_path(FDTD_FILE)
RESULT_FILE      = norm_path(RESULT_FILE)
VALID_FILE       = norm_path(VALID_FILE)
STRUCT_DATA_PATH = norm_path(STRUCT_DATA_PATH)
LOG_FILE         = norm_path(LOG_FILE)
PROGRESS_FILE    = norm_path(PROGRESS_FILE)

# ==========================
# 2. 파라미터
# ==========================
LAYER_MAP       = "1:0"
TARGET_MATERIAL = "Si3N4 (Silicon Nitride) - Phillip"
Z_min, Z_max    = 0e-9, 600e-9

START_IDX       = 0
NUM_RUNS        = 100000          # 최대 실행 개수(데이터셋 길이보다 크면 자동으로 잘림)
SPECTRAL_POINTS = 301

RESUME_IDX      = 0               # 시작 인덱스(체크포인트/커밋 기준이 우선)
CHUNK_SIZE      = 100             # (선택) 100~200 권장 (이미 반영한 값 유지)

OUT_DTYPE       = np.float32

# 디버깅/확인용 시각화
LIVE_PLOT       = True            # 저장/결과 확인하려면 True
PLOT_EVERY      = 50              # 1이면 tqdm/출력 충돌 + 매우 느림 (20~100 권장)

# tqdm postfix 갱신 주기(초)
POSTFIX_EVERY_SEC = 2.0

# ✅ 세션 로드 재시도 파라미터 (FDTD load 단계 불안정 대응)
MAX_LOAD_RETRY = 5
LOAD_RETRY_SLEEP_SEC = 5.0

# ✅ 좀비 프로세스 정리 파라미터
KILL_ON_LOAD_FAIL = True
KILL_COOLDOWN_SEC = 2.0

# ==========================
# ✅ (추가) 단계별 타임아웃 (중지되기 쉬운 지점에 적용)
# ==========================
TIMEOUT_SESSION_CREATE_SEC  = 60       # lumapi.FDTD(hide=True)
TIMEOUT_READY_PING_SEC      = 60       # wait_fdtd_ready()
TIMEOUT_LOAD_FSP_SEC        = 60      # fdtd.load()
TIMEOUT_SWITCH_LAYOUT_SEC   = 60       # fdtd.switchtolayout()
TIMEOUT_GDSIMPORT_EVAL_SEC  = 60      # fdtd.eval(gdsimport script)
TIMEOUT_RUN_SEC             = 60 * 3  # fdtd.run() (예: 30분)
TIMEOUT_EXTRACT_SEC         = 60      # fdtd.eval(EXTRACT_SCRIPT) + getv
TIMEOUT_CLOSE_SEC           = 60       # fdtd.close()

# ==========================
# 3. 로깅 / 체크포인트
# ==========================
def log_failure(struct_idx: int, stage: str, msg: str, exc: Exception = None, extra: dict = None):
    ts = time.strftime("%Y-%m-%d %H:%M:%S")
    line = f"[{ts}] struct_idx={struct_idx} stage={stage} msg={msg}\n"
    if extra:
        line += f"  extra={extra}\n"
    if exc is not None:
        line += "  " + "".join(traceback.format_exception(type(exc), exc, exc.__traceback__)) + "\n"
    with open(LOG_FILE, "a", encoding="utf-8") as f:
        f.write(line)

def save_progress(last_committed_idx: int):
    with open(PROGRESS_FILE, "w", encoding="utf-8") as f:
        f.write(str(int(last_committed_idx)))

def load_progress(default: int) -> int:
    if not os.path.exists(PROGRESS_FILE):
        return int(default)
    try:
        with open(PROGRESS_FILE, "r", encoding="utf-8") as f:
            s = f.read().strip()
        if s == "":
            return int(default)
        return int(s)
    except Exception as e:
        log_failure(-1, "load_progress", "failed to read progress file", e, extra={"path": PROGRESS_FILE})
        return int(default)

# ==========================
# 3.5 좀비 프로세스 정리 유틸 (PID 기반)
# ==========================
def kill_fdtd_processes(reason: str, struct_idx: int = -1, extra: dict = None):
    """
    Windows에서 'fdtd'가 포함된 프로세스를 tasklist로 찾아 PID 기준으로 강제 종료.
    - /F: 강제 종료
    - /T: 자식 프로세스까지 종료
    + tasklist 스냅샷/매칭 결과 로그에 남김
    """
    extra = dict(extra or {})
    extra.update({"reason": reason})

    # 1) tasklist 스냅샷 확보 (로그용)
    tasklist_stdout = ""
    try:
        cp_list = subprocess.run(
            ["tasklist", "/FO", "CSV", "/NH"],
            capture_output=True,
            text=True
        )
        tasklist_stdout = cp_list.stdout or ""
        tasklist_stderr = cp_list.stderr or ""
        log_failure(
            struct_idx, "tasklist",
            f"tasklist executed (rc={cp_list.returncode})",
            extra={
                **extra,
                "stdout_tail": tasklist_stdout[-2000:],
                "stderr_tail": tasklist_stderr[-2000:]
            }
        )
    except Exception as e:
        log_failure(struct_idx, "tasklist_error", "tasklist failed", e, extra=extra)

    # 2) CSV 파싱하여 'fdtd' 포함 프로세스 PID 수집
    matched = []
    pids = []
    try:
        rows = list(csv.reader(StringIO(tasklist_stdout)))
        for r in rows:
            if not r or len(r) < 2:
                continue
            imagename = (r[0] or "").strip().strip('"')
            pid = (r[1] or "").strip().strip('"')
            if "fdtd" in imagename.lower():
                info = {
                    "image": imagename,
                    "pid": pid,
                    "session": r[2].strip().strip('"') if len(r) > 2 else "",
                    "mem": r[4].strip().strip('"') if len(r) > 4 else ""
                }
                matched.append(info)
                if pid.isdigit():
                    pids.append(pid)

        log_failure(
            struct_idx, "tasklist_match",
            f"matched fdtd processes: {len(pids)}",
            extra={**extra, "matched": matched}
        )
    except Exception as e:
        log_failure(struct_idx, "tasklist_parse_error", "failed to parse tasklist output", e, extra=extra)

    # 3) PID 기준 강제 종료
    for pid in pids:
        try:
            cpk = subprocess.run(
                ["taskkill", "/F", "/T", "/PID", pid],
                capture_output=True,
                text=True
            )
            log_failure(
                struct_idx, "taskkill_pid",
                f"taskkill executed for pid={pid} (rc={cpk.returncode})",
                extra={**extra, "stdout": (cpk.stdout or "")[-500:], "stderr": (cpk.stderr or "")[-500:]}
            )
        except Exception as e:
            log_failure(struct_idx, "taskkill_pid_error", f"taskkill failed for pid={pid}", e, extra=extra)

    time.sleep(KILL_COOLDOWN_SEC)
    try:
        gc.collect()
    except Exception:
        pass

# ==========================
# 3.6 FDTD 준비(Ready) 핸드셰이크
# ==========================
def wait_fdtd_ready(fdtd, timeout_sec: float = 30.0, poll_sec: float = 0.5):
    """
    FDTD 프로세스가 초기화되어 lumapi 호출을 받을 준비가 될 때까지 가벼운 eval로 핑(ping).
    """
    t0 = time.time()
    last_exc = None
    while (time.time() - t0) < timeout_sec:
        try:
            fdtd.eval("1+1;")  # 최소 핑
            return
        except Exception as e:
            last_exc = e
            time.sleep(poll_sec)
    raise RuntimeError("FDTD not ready (ping timeout)") from last_exc

# ==========================
# ✅ (추가) 단계별 타임아웃 + 강제종료 + 재시도용 래퍼
# ==========================
def _stage_timeout_guard(stage: str, timeout_sec: float, struct_idx: int, chunk: tuple, extra: dict = None):
    """
    - 별도 타이머 스레드가 timeout이 지나면 fdtd 프로세스 강제 종료
    - 호출이 반환된 후에도 timeout이 발동했던 경우엔 RuntimeError로 재시도 유도
    """
    done = threading.Event()
    fired = {"v": False}
    extra = dict(extra or {})
    extra.update({"stage": stage, "timeout_sec": float(timeout_sec), "chunk": tuple(chunk)})

    def _timer():
        if not done.wait(timeout_sec):
            fired["v"] = True
            log_failure(struct_idx, "timeout", f"stage timed out: {stage}", extra=extra)
            kill_fdtd_processes(reason=f"timeout_{stage}", struct_idx=struct_idx, extra=extra)

    th = threading.Thread(target=_timer, daemon=True)
    th.start()
    return done, fired

def run_stage_with_timeout(stage: str, timeout_sec: float, struct_idx: int, chunk: tuple, fn, extra: dict = None):
    """
    fn() 실행을 감싸서, 타임아웃 발생 시 fdtd 프로세스 강제 종료 후 RuntimeError를 던져
    바깥 retry 로직으로 '재실행(새 세션)' 되게 만든다.
    """
    done, fired = _stage_timeout_guard(stage, timeout_sec, struct_idx, chunk, extra=extra)
    try:
        return fn()
    finally:
        done.set()
        if fired["v"]:
            # timeout이 한 번이라도 발동했으면, 결과를 신뢰하지 않고 상위에서 재시도
            raise RuntimeError(f"Stage timeout fired: {stage}")

def safe_close_fdtd(fdtd, struct_idx: int, chunk: tuple):
    if fdtd is None:
        return
    try:
        def _close():
            try:
                fdtd.close()
            except Exception:
                pass
        run_stage_with_timeout("close", TIMEOUT_CLOSE_SEC, struct_idx, chunk, _close)
    except Exception as e:
        # close 중 타임아웃/오류는 로그만 남기고 진행 (어차피 프로세스는 kill 시도됨)
        log_failure(struct_idx, "close_error", "fdtd close failed or timed out", e, extra={"chunk": tuple(chunk)})

# ==========================
# 4. memmap 유틸 (결과 + valid 2-phase)
# ==========================
def open_or_create_result_memmap(path: str, shape: tuple, dtype=np.float32):
    if os.path.exists(path):
        try:
            arr = np.load(path, mmap_mode="r+")
            if arr.shape == shape and arr.dtype == dtype:
                print(f"✅ 기존 결과 memmap 사용: {path} shape={arr.shape} dtype={arr.dtype}")
                return arr

            print(f"⚠️ 기존 결과 파일 shape/dtype 불일치: {arr.shape}/{arr.dtype} -> 새로 생성 후 일부 복사")
            tmp_path = path.replace(".npy", f".tmp_{int(time.time())}.npy")
            new_arr = np.lib.format.open_memmap(tmp_path, mode="w+", dtype=dtype, shape=shape)

            o0 = min(arr.shape[0], shape[0])
            o1 = min(arr.shape[1], shape[1])
            o2 = min(arr.shape[2], shape[2])
            new_arr[:o0, :o1, :o2] = arr[:o0, :o1, :o2].astype(dtype, copy=False)
            new_arr.flush()
            del new_arr, arr

            os.replace(tmp_path, path)
            arr2 = np.load(path, mmap_mode="r+")
            print(f"✅ 결과 파일 재생성 완료(memmap): {path} shape={arr2.shape} dtype={arr2.dtype}")
            return arr2
        except Exception as e:
            log_failure(-1, "open_memmap", "failed to open existing result file", e, extra={"path": path})

    arr = np.lib.format.open_memmap(path, mode="w+", dtype=dtype, shape=shape)
    arr[:] = 0
    arr.flush()
    print(f"✨ 새 결과 memmap 생성: {path} shape={shape} dtype={dtype}")
    return arr

def open_or_create_valid_memmap(path: str, length: int):
    if os.path.exists(path):
        try:
            v = np.load(path, mmap_mode="r+")
            if v.shape == (length,) and v.dtype == np.uint8:
                print(f"✅ valid memmap 사용: {path} shape={v.shape}")
                return v

            print(f"⚠️ valid 파일 길이/형식 불일치: {v.shape}/{v.dtype} -> 새로 생성 후 일부 복사")
            tmp_path = path.replace(".npy", f".tmp_{int(time.time())}.npy")
            new_v = np.lib.format.open_memmap(tmp_path, mode="w+", dtype=np.uint8, shape=(length,))
            new_v[:] = 0
            n = min(v.shape[0], length)
            new_v[:n] = np.array(v[:n], dtype=np.uint8, copy=False)
            new_v.flush()
            del new_v, v
            os.replace(tmp_path, path)
            v2 = np.load(path, mmap_mode="r+")
            return v2
        except Exception as e:
            log_failure(-1, "open_valid", "failed to open existing valid file", e, extra={"path": path})

    v = np.lib.format.open_memmap(path, mode="w+", dtype=np.uint8, shape=(length,))
    v[:] = 0
    v.flush()
    print(f"✨ valid memmap 생성: {path} shape={v.shape}")
    return v

# ==========================
# 5. 데이터 로드 (인덱스 정합성 기준)
# ==========================
if os.path.exists(STRUCT_DATA_PATH):
    print(f"📂 구조 데이터 로드: {STRUCT_DATA_PATH}")
    struct_data = np.load(STRUCT_DATA_PATH, mmap_mode="r")
else:
    raise FileNotFoundError(f"❌ 구조 파일 없음: {STRUCT_DATA_PATH}")

N_STRUCT = int(struct_data.shape[0])

all_spectra = open_or_create_result_memmap(
    RESULT_FILE, (N_STRUCT, 3, SPECTRAL_POINTS), dtype=OUT_DTYPE
)
valid_mask = open_or_create_valid_memmap(VALID_FILE, N_STRUCT)

# 실행 범위 클램프
START_IDX = max(0, int(START_IDX))
END_IDX_EXCL = min(N_STRUCT, START_IDX + int(NUM_RUNS))

# 미커밋(2) 흔적은 0으로 되돌림 (실행 범위만 스캔)
_vm_sub = np.asarray(valid_mask[START_IDX:END_IDX_EXCL])
_stale_rel = np.where(_vm_sub == 2)[0]
if _stale_rel.size > 0:
    _stale_abs = _stale_rel + START_IDX
    valid_mask[_stale_abs] = 0
    valid_mask.flush()

# ✅ 재개 인덱스: "마지막 커밋 기준"
last_committed_from_file = load_progress(default=START_IDX - 1)
resume_from_checkpoint = last_committed_from_file + 1

user_resume = max(START_IDX, int(RESUME_IDX))
RESUME_IDX = max(user_resume, resume_from_checkpoint)
RESUME_IDX = min(RESUME_IDX, END_IDX_EXCL)

# 안전장치: 이미 커밋된(valid==1) 구간은 앞으로 스킵
while RESUME_IDX < END_IDX_EXCL and int(valid_mask[RESUME_IDX]) == 1:
    RESUME_IDX += 1

print(f"📌 dataset length(N_STRUCT) = {N_STRUCT}")
print(f"🚀 실행 범위: {START_IDX} ~ {END_IDX_EXCL-1} (총 {END_IDX_EXCL-START_IDX})")
print(f"🧠 세션 리셋 주기: {CHUNK_SIZE}")
print(f"📝 로그: {LOG_FILE}")
print(f"🔁 재개 인덱스(체크포인트/커밋 기준): {RESUME_IDX} (progress last_committed={last_committed_from_file})")

# ==========================
# 6. 시각화 함수
# ==========================
PLOT_HANDLE = None  # 노트북에서 같은 출력 영역 업데이트용

def plot_live_status(struct_idx, image_data, spectra, wavelength=None, valid_state=None):
    global PLOT_HANDLE

    try:
        fig, axes = plt.subplots(1, 2, figsize=(14, 5))

        ax_img = axes[0]
        ax_img.imshow(image_data.squeeze(), cmap="gray", origin="lower")
        ax_img.set_title(f"Structure [{struct_idx}] (valid={valid_state})")
        ax_img.axis("off")

        ax_plot = axes[1]
        x_axis = wavelength if wavelength is not None else np.arange(len(spectra[0]))
        x_label = "Wavelength (nm)" if wavelength is not None else "Index"

        ax_plot.plot(x_axis, -spectra[0], "r-", label="Trans_1")
        ax_plot.plot(x_axis, -spectra[1], "g-", label="Trans_2")
        ax_plot.plot(x_axis, -spectra[2], "b-", label="Trans_3")

        ax_plot.set_title(f"Transmission Spectra [{struct_idx}]")
        ax_plot.set_xlabel(x_label)
        ax_plot.set_ylim(-0.05, 1.05)
        ax_plot.legend()
        ax_plot.grid(True, alpha=0.3)

        plt.tight_layout()

        # ✅ clear_output 없이 같은 출력 영역만 업데이트
        if PLOT_HANDLE is None:
            PLOT_HANDLE = display(fig, display_id=True)
        else:
            PLOT_HANDLE.update(fig)

        plt.close(fig)

    except Exception as e:
        print(f"❌ Plot Error 발생: {e}")

# ==========================
# 7. GDS import 스크립트
# ==========================
def script_import_like_original(gds_path: str, struct_idx: int) -> str:
    cellA = f"structure_{struct_idx:05d}"
    cellB = f"structure_{struct_idx}"
    return f'''
try{{ select("IMPORTED_GDS"); delete; }} catch(errMsg);

import_ok = 0;
used_cell = "";
import_err = "";

try{{
    gdsimport("{gds_path}", "{cellA}", "{LAYER_MAP}", "{TARGET_MATERIAL}", {Z_min}, {Z_max});
    set("name", "IMPORTED_GDS");
    import_ok = 1;
    used_cell = "{cellA}";
}} catch(import_err);

if (import_ok == 0) {{
    import_err = "";
    try{{
        gdsimport("{gds_path}", "{cellB}", "{LAYER_MAP}", "{TARGET_MATERIAL}", {Z_min}, {Z_max});
        set("name", "IMPORTED_GDS");
        import_ok = 1;
        used_cell = "{cellB}";
    }} catch(import_err);
}}
'''

# ==========================
# 8. 결과 추출 스크립트 (원본 방식)
# ==========================
EXTRACT_SCRIPT = '''
if (haveresult("Trans_1")) { T1=transmission("Trans_1"); f_vec=getdata("Trans_1","f"); } else { T1=0; f_vec=0; }
if (haveresult("Trans_2")) { T2=transmission("Trans_2"); } else { T2=0; }
if (haveresult("Trans_3")) { T3=transmission("Trans_3"); } else { T3=0; }
'''

# ==========================
# 9. 메인 루프
# ==========================
print(f"\n🚀 FDTD 실행 시작 (struct_idx={RESUME_IDX}부터)\n")

wavelength_data = None
last_committed = RESUME_IDX - 1

total_total = END_IDX_EXCL - START_IDX
total_initial = RESUME_IDX - START_IDX

ok_cnt = 0
fail_cnt = 0
skip_cnt = 0

last_postfix_t = time.time()

# ✅ tqdm 한 줄 유지 + 청크 이동 메시지는 postfix로만 표시
with tqdm(
    total=total_total,
    initial=total_initial,
    desc="Total",
    dynamic_ncols=True,
    leave=True,
    mininterval=0.2,
    ascii=False
) as pbar:

    # 초기 postfix
    pbar.set_postfix_str(f"chunk={RESUME_IDX}~{min(RESUME_IDX+CHUNK_SIZE-1, END_IDX_EXCL-1)}")

    for chunk_start in range(RESUME_IDX, END_IDX_EXCL, CHUNK_SIZE):
        chunk_end = min(chunk_start + CHUNK_SIZE, END_IDX_EXCL)

        pbar.set_postfix_str(
            f"chunk={chunk_start}~{chunk_end-1} idx={chunk_start} ok={ok_cnt} fail={fail_cnt} skip={skip_cnt}"
        )

        chunk_success = []
        current_idx_for_postfix = chunk_start

        loaded = False
        last_load_exc = None

        for attempt in range(1, MAX_LOAD_RETRY + 1):
            fdtd = None
            try:
                # ✅ (추가) 세션 생성에도 타임아웃
                def _create_session():
                    return lumapi.FDTD(hide=True)

                fdtd = run_stage_with_timeout(
                    "session_create",
                    TIMEOUT_SESSION_CREATE_SEC,
                    struct_idx=chunk_start,
                    chunk=(chunk_start, chunk_end-1),
                    fn=_create_session
                )

                # ✅ (추가) ready ping 타임아웃
                run_stage_with_timeout(
                    "ready_ping",
                    TIMEOUT_READY_PING_SEC,
                    struct_idx=chunk_start,
                    chunk=(chunk_start, chunk_end-1),
                    fn=lambda: wait_fdtd_ready(fdtd, timeout_sec=TIMEOUT_READY_PING_SEC, poll_sec=0.5)
                )

                # ✅ (추가) load 타임아웃
                run_stage_with_timeout(
                    "load_fsp",
                    TIMEOUT_LOAD_FSP_SEC,
                    struct_idx=chunk_start,
                    chunk=(chunk_start, chunk_end-1),
                    fn=lambda: fdtd.load(FDTD_FILE)
                )

                loaded = True

                for struct_idx in range(chunk_start, chunk_end):
                    current_idx_for_postfix = struct_idx
                    try:
                        if int(valid_mask[struct_idx]) == 1:
                            skip_cnt += 1
                            continue

                        # ✅ (추가) switchtolayout 타임아웃
                        run_stage_with_timeout(
                            "switchtolayout",
                            TIMEOUT_SWITCH_LAYOUT_SEC,
                            struct_idx=struct_idx,
                            chunk=(chunk_start, chunk_end-1),
                            fn=lambda: fdtd.switchtolayout()
                        )

                        gdsA = os.path.join(GDS_DIR, f"structure_{struct_idx:05d}.gds")
                        gdsB = os.path.join(GDS_DIR, f"structure_{struct_idx}.gds")

                        if os.path.exists(gdsA):
                            gds_path = norm_path(gdsA)
                        elif os.path.exists(gdsB):
                            gds_path = norm_path(gdsB)
                        else:
                            fail_cnt += 1
                            log_failure(struct_idx, "gds_missing", "GDS file not found", extra={"A": gdsA, "B": gdsB})
                            continue

                        # ✅ (추가) gdsimport eval 타임아웃
                        try:
                            run_stage_with_timeout(
                                "gdsimport_eval",
                                TIMEOUT_GDSIMPORT_EVAL_SEC,
                                struct_idx=struct_idx,
                                chunk=(chunk_start, chunk_end-1),
                                fn=lambda: fdtd.eval(script_import_like_original(gds_path, struct_idx)),
                                extra={"gds_path": gds_path}
                            )
                            import_ok = int(np.array(fdtd.getv("import_ok")).ravel()[0])
                        except Exception as e:
                            # timeout도 여기로 들어온다(raise RuntimeError). -> fail 처리
                            fail_cnt += 1
                            log_failure(struct_idx, "gdsimport_eval", "eval failed during gdsimport (or timeout)", e, extra={"gds_path": gds_path})
                            continue

                        if import_ok != 1:
                            fail_cnt += 1
                            try:
                                import_err = fdtd.getv("import_err")
                                used_cell = fdtd.getv("used_cell")
                            except Exception:
                                import_err, used_cell = "<unreadable>", "<unreadable>"
                            log_failure(
                                struct_idx, "gdsimport", "gdsimport failed",
                                extra={"gds_path": gds_path, "used_cell": str(used_cell), "import_err": str(import_err)}
                            )
                            continue

                        # ✅ (추가) run 타임아웃
                        try:
                            run_stage_with_timeout(
                                "run",
                                TIMEOUT_RUN_SEC,
                                struct_idx=struct_idx,
                                chunk=(chunk_start, chunk_end-1),
                                fn=lambda: fdtd.run(),
                                extra={"gds_path": gds_path}
                            )
                        except Exception as e:
                            fail_cnt += 1
                            log_failure(struct_idx, "run", "fdtd.run() failed (or timeout)", e, extra={"gds_path": gds_path})
                            # 레이아웃으로 돌아가기(이것도 타임아웃 보호)
                            try:
                                run_stage_with_timeout(
                                    "switchtolayout_after_run_fail",
                                    TIMEOUT_SWITCH_LAYOUT_SEC,
                                    struct_idx=struct_idx,
                                    chunk=(chunk_start, chunk_end-1),
                                    fn=lambda: fdtd.switchtolayout()
                                )
                            except Exception:
                                pass
                            continue

                        # ✅ (추가) extract 타임아웃 (eval + getv 전체를 하나로)
                        try:
                            def _extract_all():
                                fdtd.eval(EXTRACT_SCRIPT)
                                r1 = np.array(fdtd.getv("T1")).ravel()
                                r2 = np.array(fdtd.getv("T2")).ravel()
                                r3 = np.array(fdtd.getv("T3")).ravel()

                                nonlocal_wavelength = None
                                if nonlocal_wavelength is None:
                                    f_data = np.array(fdtd.getv("f_vec")).ravel()
                                    return r1, r2, r3, f_data
                                return r1, r2, r3, None

                            r1, r2, r3, f_data = run_stage_with_timeout(
                                "extract",
                                TIMEOUT_EXTRACT_SEC,
                                struct_idx=struct_idx,
                                chunk=(chunk_start, chunk_end-1),
                                fn=_extract_all,
                                extra={"gds_path": gds_path}
                            )

                            if wavelength_data is None and f_data is not None:
                                if f_data.size > 1:
                                    wavelength_data = (299792458.0 / f_data) * 1e9

                        except Exception as e:
                            fail_cnt += 1
                            log_failure(struct_idx, "extract", "failed to extract results (or timeout)", e, extra={"gds_path": gds_path})
                            continue

                        if r1.size != SPECTRAL_POINTS or r2.size != SPECTRAL_POINTS or r3.size != SPECTRAL_POINTS:
                            fail_cnt += 1
                            log_failure(
                                struct_idx, "shape_mismatch", "spectra length mismatch",
                                extra={"sizes": (int(r1.size), int(r2.size), int(r3.size)), "gds_path": gds_path}
                            )
                            continue

                        current_spectra = np.stack([r1, r2, r3], axis=0).astype(OUT_DTYPE, copy=False)

                        valid_mask[struct_idx] = 2
                        all_spectra[struct_idx, :, :] = current_spectra
                        chunk_success.append(struct_idx)
                        ok_cnt += 1

                        if LIVE_PLOT and (struct_idx % PLOT_EVERY == 0):
                            plot_live_status(
                                struct_idx,
                                struct_data[struct_idx],
                                current_spectra,
                                wavelength_data,
                                valid_state=int(valid_mask[struct_idx])
                            )

                    finally:
                        pbar.update(1)

                        now = time.time()
                        if now - last_postfix_t >= POSTFIX_EVERY_SEC:
                            pbar.set_postfix_str(
                                f"chunk={chunk_start}~{chunk_end-1} "
                                f"idx={current_idx_for_postfix} ok={ok_cnt} fail={fail_cnt} skip={skip_cnt}"
                            )
                            last_postfix_t = now

                all_spectra.flush()
                if chunk_success:
                    valid_mask[np.array(chunk_success, dtype=np.int64)] = 1
                valid_mask.flush()

                if chunk_success:
                    last_committed = max(last_committed, max(chunk_success))
                    save_progress(last_committed)

                break  # 성공적으로 청크 완료

            except Exception as e:
                last_load_exc = e
                log_failure(
                    chunk_start, "session_load_retry",
                    f"FDTD session/load failed (attempt {attempt}/{MAX_LOAD_RETRY})",
                    e, extra={"chunk": (chunk_start, chunk_end-1)}
                )

                # ✅ (추가) 실패/타임아웃이면 항상 fdtd 프로세스 정리 (PID 기반)
                if KILL_ON_LOAD_FAIL:
                    kill_fdtd_processes(
                        reason="retry_after_exception_or_timeout",
                        struct_idx=chunk_start,
                        extra={"attempt": attempt, "chunk": (chunk_start, chunk_end-1)}
                    )

                try:
                    gc.collect()
                except Exception:
                    pass
                time.sleep(LOAD_RETRY_SLEEP_SEC)

            finally:
                # ✅ (추가) close도 타임아웃 보호 + 실패 시 kill
                try:
                    safe_close_fdtd(fdtd, struct_idx=chunk_start, chunk=(chunk_start, chunk_end-1))
                except Exception:
                    pass
                fdtd = None

        if not loaded:
            log_failure(
                chunk_start, "session",
                "FDTD session crashed (load unrecoverable)",
                last_load_exc, extra={"chunk": (chunk_start, chunk_end-1)}
            )

            if KILL_ON_LOAD_FAIL:
                kill_fdtd_processes(
                    reason="load_unrecoverable",
                    struct_idx=chunk_start,
                    extra={"chunk": (chunk_start, chunk_end-1)}
                )
            continue

print("\n🎉 완료")
print(f"✅ 마지막 커밋 struct_idx: {last_committed}")
print(f"📝 실패 로그: {LOG_FILE}")
print(f"🧾 체크포인트: {PROGRESS_FILE}")
# Out:
# 📂 구조 데이터 로드: D:/dataset/binary_dataset_128_1.npy
# ✅ 기존 결과 memmap 사용: D:/dataset/spectra_result/spectra_latest_1.npy shape=(100000, 3, 301) dtype=float32
# ✅ valid memmap 사용: D:/dataset/spectra_result/spectra_latest_valid_1.npy shape=(100000,)
# 📌 dataset length(N_STRUCT) = 100000
# 🚀 실행 범위: 0 ~ 99999 (총 100000)
# 🧠 세션 리셋 주기: 100
# 📝 로그: D:/dataset/spectra_result/run_failures.log
# 🔁 재개 인덱스(체크포인트/커밋 기준): 42200 (progress last_committed=42199)
#
# 🚀 FDTD 실행 시작 (struct_idx=42200부터)
# Total:  42%|███████████▊                | 42200/100000 [00:00<?, ?it/s, chunk=42200~42299 idx=42200 ok=0 fail=0 skip=0]

# %%
import os, numpy as np, datetime

RESULT_FILE = r"D:\dataset\spectra_result\spectra_latest_1.npy"
VALID_FILE  = r"D:\dataset\spectra_result\spectra_latest_valid_1.npy"
PROGRESS_FILE = r"D:\dataset\spectra_result\progress_checkpoint_1.txt"

def stat(p):
    st = os.stat(p)
    return {
        "path": p,
        "size_GB": st.st_size / (1024**3),
        "mtime": datetime.datetime.fromtimestamp(st.st_mtime),
    }

print("== file stat ==")
print(stat(RESULT_FILE))
print(stat(VALID_FILE))
print("progress exists:", os.path.exists(PROGRESS_FILE))
if os.path.exists(PROGRESS_FILE):
    print("progress:", open(PROGRESS_FILE, "r", encoding="utf-8").read().strip())

print("\n== read & count ==")
spec = np.load(RESULT_FILE, mmap_mode="r")
val  = np.load(VALID_FILE,  mmap_mode="r")

u, c = np.unique(val, return_counts=True)
print("valid counts:", dict(zip(u.tolist(), c.tolist())))

# 0이 아닌 row(=뭔가 써진 적 있는 구조) 수
nonzero_rows = np.where(np.any(spec != 0, axis=(1,2)))[0]
print("nonzero rows:", nonzero_rows.size)
if nonzero_rows.size:
    print("first/last nonzero idx:", int(nonzero_rows[0]), int(nonzero_rows[-1]))
# Out:
# == file stat ==
# {'path': 'D:\\dataset\\spectra_result\\spectra_latest_1.npy', 'size_GB': 0.3363938331604004, 'mtime': datetime.datetime(2026, 1, 19, 14, 45, 18, 277513)}
# {'path': 'D:\\dataset\\spectra_result\\spectra_latest_valid_1.npy', 'size_GB': 9.325146675109863e-05, 'mtime': datetime.datetime(2026, 1, 19, 14, 45, 20, 17028)}
# progress exists: True
# progress: 24799
#
# == read & count ==
# valid counts: {0: 75195, 1: 24800, 2: 5}
# nonzero rows: 24805
# first/last nonzero idx: 0 24804

# %%
import os, numpy as np, datetime

RESULT_FILE = r"D:\dataset\spectra_result\spectra_latest_1.npy"
VALID_FILE  = r"D:\dataset\spectra_result\spectra_latest_valid_1.npy"
PROGRESS_FILE = r"D:\dataset\spectra_result\progress_checkpoint_1.txt"

def stat(p):
    st = os.stat(p)
    return {
        "path": p,
        "size_GB": st.st_size / (1024**3),
        "mtime": datetime.datetime.fromtimestamp(st.st_mtime),
    }

print("== file stat ==")
print(stat(RESULT_FILE))
print(stat(VALID_FILE))
print("progress exists:", os.path.exists(PROGRESS_FILE))
if os.path.exists(PROGRESS_FILE):
    print("progress:", open(PROGRESS_FILE, "r", encoding="utf-8").read().strip())

print("\n== read & count ==")
spec = np.load(RESULT_FILE, mmap_mode="r")
val  = np.load(VALID_FILE,  mmap_mode="r")

u, c = np.unique(val, return_counts=True)
print("valid counts:", dict(zip(u.tolist(), c.tolist())))

# 0이 아닌 row(=뭔가 써진 적 있는 구조) 수
nonzero_rows = np.where(np.any(spec != 0, axis=(1,2)))[0]
print("nonzero rows:", nonzero_rows.size)
if nonzero_rows.size:
    print("first/last nonzero idx:", int(nonzero_rows[0]), int(nonzero_rows[-1]))
# Out:
# == file stat ==
# {'path': 'D:\\dataset\\spectra_result\\spectra_latest_1.npy', 'size_GB': 0.3363938331604004, 'mtime': datetime.datetime(2026, 1, 19, 14, 45, 18, 277513)}
# {'path': 'D:\\dataset\\spectra_result\\spectra_latest_valid_1.npy', 'size_GB': 9.325146675109863e-05, 'mtime': datetime.datetime(2026, 1, 19, 14, 45, 20, 17028)}
# progress exists: True
# progress: 24799
#
# == read & count ==
# valid counts: {0: 75195, 1: 24800, 2: 5}
# nonzero rows: 24805
# first/last nonzero idx: 0 24804

# %%
import numpy as np

VALID_FILE  = r"D:\dataset\spectra_result\spectra_latest_valid_1.npy"
VALID_RECOVER = r"D:\dataset\spectra_result\spectra_latest_valid_1_RECOVERED.npy"

v = np.load(VALID_FILE, mmap_mode="r")
v2 = np.array(v, dtype=np.uint8, copy=True)
v2[v2 == 2] = 1
np.save(VALID_RECOVER, v2)

print("saved:", VALID_RECOVER)
u, c = np.unique(v2, return_counts=True)
print("recovered valid counts:", dict(zip(u.tolist(), c.tolist())))
print("last_committed:", int(np.where(v2 == 1)[0].max()))
# Out:
# saved: D:\dataset\spectra_result\spectra_latest_valid_1_RECOVERED.npy
# recovered valid counts: {0: 57800, 1: 42200}
# last_committed: 42199

# %%
import numpy as np
spec = np.load(r"D:\dataset\spectra_result\spectra_latest_1.npy", mmap_mode="r")
val  = np.load(r"D:\dataset\spectra_result\spectra_latest_valid_1.npy", mmap_mode="r")

print(spec.shape, spec.dtype)  # (100000, 3, 301) float32 이어야 정상
print("example sum:", float(np.sum(np.abs(spec[100]))), "valid:", int(val[100]))
# Out:
# (100000, 3, 301) float32
# example sum: 228.67929077148438 valid: 1
